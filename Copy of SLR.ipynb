# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("/content/Salary_dataset.csv")

# %%
dataset
# Out:
#     YearsExperience  Salary
# 0               1.2   39344
# 1               1.4   46206
# 2               1.6   37732
# 3               2.1   43526
# 4               2.3   39892
# 5               3.0   56643
# 6               3.1   60151
# 7               3.3   54446
# 8               3.3   64446
# 9               3.8   57190
# 10              4.0   63219
# 11              4.1   55795
# 12              4.1   56958
# 13              4.2   57082
# 14              4.6   61112
# 15              5.0   67939
# 16              5.2   66030
# 17              5.4   83089
# 18              6.0   81364
# 19              6.1   93941
# 20              6.9   91739
# 21              7.2   98274
# 22              8.0  101303
# 23              8.3  113813
# 24              8.8  109432
# 25              9.1  105583
# 26              9.6  116970
# 27              9.7  112636
# 28             10.4  122392
# 29             10.6  121873

# %%
plt.scatter(dataset['YearsExperience'],dataset['Salary'])
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title("Salary vs Experience")
plt.show()

# %%
dataset.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
sns.heatmap(dataset.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(dataset)

# %%
X=dataset[['YearsExperience']]

# %%
X
# Out:
#     YearsExperience
# 0               1.2
# 1               1.4
# 2               1.6
# 3               2.1
# 4               2.3
# 5               3.0
# 6               3.1
# 7               3.3
# 8               3.3
# 9               3.8
# 10              4.0
# 11              4.1
# 12              4.1
# 13              4.2
# 14              4.6
# 15              5.0
# 16              5.2
# 17              5.4
# 18              6.0
# 19              6.1
# 20              6.9
# 21              7.2
# 22              8.0
# 23              8.3
# 24              8.8
# 25              9.1
# 26              9.6
# 27              9.7
# 28             10.4
# 29             10.6

# %%
X.shape
# Out:
# (30, 1)

# %%
Y=dataset[['Salary']]
Y.shape
# Out:
# (30, 1)

# %%
Y.head()
# Out:
#    Salary
# 0   39344
# 1   46206
# 2   37732
# 3   43526
# 4   39892

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=4)

# %%
X_train
# Out:
#     YearsExperience
# 17              5.4
# 29             10.6
# 19              6.1
# 0               1.2
# 3               2.1
# 16              5.2
# 10              4.0
# 6               3.1
# 12              4.1
# 2               1.6
# 4               2.3
# 22              8.0
# 13              4.2
# 7               3.3
# 9               3.8
# 18              6.0
# 24              8.8
# 27              9.7
# 8               3.3
# 1               1.4
# 5               3.0
# 23              8.3
# 14              4.6
# 26              9.6

# %%
Y_train
# Out:
#     Salary
# 17   83089
# 29  121873
# 19   93941
# 0    39344
# 3    43526
# 16   66030
# 10   63219
# 6    60151
# 12   56958
# 2    37732
# 4    39892
# 22  101303
# 13   57082
# 7    54446
# 9    57190
# 18   81364
# 24  109432
# 27  112636
# 8    64446
# 1    46206
# 5    56643
# 23  113813
# 14   61112
# 26  116970

# %%
X_test
# Out:
#     YearsExperience
# 11              4.1
# 21              7.2
# 28             10.4
# 15              5.0
# 20              6.9
# 25              9.1

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[9469.6069012]])

# %%
model.intercept_
# Out:
# array([25203.58558024])

# %%
plt.scatter(X_train,Y_train)
plt.plot(X_train,model.predict(X_train),color='black')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title("Salary vs Experience")
plt.show()

# %%
plt.scatter(X_test,Y_test)
plt.plot(X_test,model.predict(X_test),color='silver')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title("Salary vs Experience")
plt.show()

# %%
model.predict([[50]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[498683.93064045]])

# %%
model.predict([[3.1]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[54559.36697398]])

# %%
model.predict([[3.6]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[59294.17042458]])

# %%
model.predict([[11]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[129369.26149349]])

# %%
model.predict([[6.9]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[90543.87319855]])

# %%
model.predict([[12.6]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[144520.63253542]])

# %%
model.predict([[77]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[754363.31697296]])

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
score=r2_score(Y_test,model.predict(X_test))

# %%
score
# Out:
# 0.9504404484884268

# %%
mse=np.sqrt(mean_squared_error(Y_test,model.predict(X_test)))

# %%
mse
# Out:
# 4994.271359298179

# %%
mae=mean_absolute_error(Y_test,model.predict(X_test))

# %%
mae
# Out:
# 4336.7452046580365
